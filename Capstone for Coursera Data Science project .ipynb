# %% [markdown]
# #    Coursera Capstone Project

# %%
import numpy as np 
import pandas as pd

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
#take out values of Boroughs with 'Not assigned' values
df_sct=df_sc[df_sc.Borough != 'Not assigned']

# %%
# This is the Second part of the Capstone project segment ' Segmenting and Clustering'

# %%
#used the file provided to fetch altitude longitudes of the places
df_llt = pd.read_csv('http://cocl.us/Geospatial_data')
df_llt.head(5)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# number of rows and columns of the final dataframe
df_lalg.shape
# Out:
# (103, 5)

# %%
# This is the 3rd and Final part of the capstone project segment 'Segmenting and Clustering'

# %%
#Installing Folium to map the neighbourhoods and Boroughs
# !pip install folium==0.5
import folium as folium
# Out:
# ...
#      |████████████████████████████████| 79 kB 9.1 MB/s  eta 0:00:01
# ...
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=d5ed355f3419dcc1486bdc2b42471ce4615774632ba7675e1f2caf43a7e08e87
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# ...

# %%
#Toronto map
Toronto_map = folium.Map(location=[43.6532, -79.3832], zoom_start=3)

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

# add markers to map
for lat, lng, Borough, Neighbourhood in zip(df_lalg['Latitude'], df_lalg['Longitude'], df_lalg['Borough'], df_lalg['Neighbourhood']):
    label = '{}, {}'.format(Neighbourhood, Borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
       [lat, lng],
       radius=5,
       popup=label,
       color='blue',
       fill=True,
       fill_color='#3186cc',
       fill_opacity=0.7,
       parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Neighbourhood data for the borough Scarborough

Scarborough_data = df_lalg[df_lalg['Borough'] == 'Scarborough'].reset_index(drop=True)
Scarborough_data.head()
# Out:
#   Postal Code   Latitude  Longitude      Borough  \
# 0         M1B  43.806686 -79.194353  Scarborough
# 1         M1C  43.784535 -79.160497  Scarborough
# 2         M1E  43.763573 -79.188711  Scarborough
# 3         M1G  43.770992 -79.216917  Scarborough
# 4         M1H  43.773136 -79.239476  Scarborough
#
#                             Neighbourhood
# 0                          Malvern, Rouge
# 1  Rouge Hill, Port Union, Highland Creek
# 2       Guildwood, Morningside, West Hill
# 3                                  Woburn
# 4                               Cedarbrae

# %%
Scarborough_data.shape
# Out:
# (17, 5)

# %%
map_scarborough = folium.Map(location=[43.7764, -79.2318], zoom_start=10)

# %%
# 17 neighbourhoods in the Borough Scarborough


# add markers to map
for lat, lng, label in zip(Scarborough_data['Latitude'], Scarborough_data['Longitude'], Scarborough_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_scarborough)  
    
map_scarborough
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Exploring the Borough Downtown Toronto
DowntownToronto_data = df_lalg[df_lalg['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
DowntownToronto_data.head(5)
# Out:
#   Postal Code   Latitude  Longitude           Borough  \
# 0         M4W  43.679563 -79.377529  Downtown Toronto
# 1         M4X  43.667967 -79.367675  Downtown Toronto
# 2         M4Y  43.665860 -79.383160  Downtown Toronto
# 3         M5A  43.654260 -79.360636  Downtown Toronto
# 4         M5B  43.657162 -79.378937  Downtown Toronto
#
#                  Neighbourhood
# 0                     Rosedale
# 1  St. James Town, Cabbagetown
# 2         Church and Wellesley
# 3    Regent Park, Harbourfront
# 4     Garden District, Ryerson

# %%
DowntownToronto_data.shape
# Out:
# (19, 5)

# %%
map_DowntownToronto = folium.Map(location=[43.6548, -79.3883], zoom_start=10)

# %%
# 19 neighbourhoods in the Borough Downtown Toronto


# add markers to map
for lat, lng, label in zip(DowntownToronto_data['Latitude'], DowntownToronto_data['Longitude'], DowntownToronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_DowntownToronto)  
    
map_DowntownToronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# This is the Week 5 of the CAPSTONE PROJECT for COURSERA DATA SCIENCE

# %%
#Importing Demographica data for Montgomery County,Tx

import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_9c414af691d04507b17dfb2555fe491b = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ciUlFsGGOH5BfctB4TKV87F9BarCevlmIB_H5TpcJggR',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='DiversityMontgomery.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    ID Birthplace                                         Birthplace  ID Year  \
# 0             60                                     American Samoa     2018
# 1            554  Other U.S. Island Areas, Oceania, Not Specifie...     2018
# 2            527                                              Samoa     2018
# 3            523                                              Tonga     2018
# 4            515                                        New Zealand     2018
#
#    Year  ID Nativity      Nativity Country Code  Total Population  \
# 0  2018            2  Foreign born          ASM              2016
# 1  2018            2  Foreign born          NaN              1607
# 2  2018            2  Foreign born          WSM               205
# 3  2018            2  Foreign born          TON               247
# 4  2018            2  Foreign born          NZL              2613
#
#    Total Population MOE Appx Geography ID Geography
# 0                1102.312595     Texas    04000US48
# ...

# %%
 df_data_1.columns
# Out:
# Index(['ID Birthplace', 'Birthplace', 'ID Year', 'Year', 'ID Nativity',
#        'Nativity', 'Country Code', 'Total Population',
#        'Total Population MOE Appx', 'Geography', 'ID Geography'],
#       dtype='object')

# %%
df_data_1.shape
# Out:
# (799, 11)

# %%
df_mgmry= df_data_1.drop(['Year','ID Year' ,'ID Nativity','Nativity','Country Code','Total Population MOE Appx','Geography','ID Geography'], axis=1)

# %%
# Number of People with diverse ethnicities in Motgomery County, Tx
df_mgmry
# Out:
#      ID Birthplace                                         Birthplace  \
# 0               60                                     American Samoa
# 1              554  Other U.S. Island Areas, Oceania, Not Specifie...
# 2              527                                              Samoa
# 3              523                                              Tonga
# 4              515                                        New Zealand
# ..             ...                                                ...
# 794            554  Other U.S. Island Areas, Oceania, Not Specifie...
# 795            158                                            Armenia
# 796            157                                          Lithuania
# 797            156                                             Latvia
# 798            248                                              Yemen
#
#      Total Population
# 0                2016
# 1                1607
# 2                 205
# 3                 247
# ...

# %%
df_mgmry.dropna()
# Out:
#      ID Birthplace                                         Birthplace  \
# 0               60                                     American Samoa
# 1              554  Other U.S. Island Areas, Oceania, Not Specifie...
# 2              527                                              Samoa
# 3              523                                              Tonga
# 4              515                                        New Zealand
# ..             ...                                                ...
# 794            554  Other U.S. Island Areas, Oceania, Not Specifie...
# 795            158                                            Armenia
# 796            157                                          Lithuania
# 797            156                                             Latvia
# 798            248                                              Yemen
#
#      Total Population
# 0                2016
# 1                1607
# 2                 205
# 3                 247
# ...

# %%
df_mgmry.groupby('Birthplace').sum()
# Out:
#                                ID Birthplace  Total Population
# Birthplace
# Afghanistan                             1000             28783
# Africa                                  2310             74536
# Albania                                  500             10637
# Algeria                                 2000              6067
# American Samoa                            60              2016
# ...                                      ...               ...
# Western Africa, not specified           2335             12555
# Yemen                                   1240              2894
# Yugoslavia                               735              5110
# Zambia                                  2300              8429
# Zimbabwe                                2305             14452
#
# [170 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
name = df_mgmry['Birthplace'].head(10) 
diversity = df_mgmry['Total Population'].head(10) 
  
# Figure Size 
fig = plt.figure(figsize =(10, 7)) 
  # Horizontal Bar Plot 
plt.bar(name[0:10], diversity[0:10]) 
  
# Show Plot 
plt.show()

# %%
#df_mgmry['Birthplace'].value_counts().sort_index().plot.barh()
#sns.scatterplot(x='Birthplace', y='Total Population', data= df_mgmry)

# %%
body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='MgmryDiversity.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#    ID Race                             Race  ID Ethnicity  \
# 0        1  Black or African American Alone             0
# 1        6                Two or More Races             1
# 2        0                      White Alone             0
# 3        5            Some Other Race Alone             1
# 4        0                      White Alone             1
#
#                 Ethnicity  ID Year  Year  Hispanic Population Moe  \
# 0  Not Hispanic or Latino     2018  2018              2686.000000
# 1      Hispanic or Latino     2018  2018              1861.179196
# 2  Not Hispanic or Latino     2018  2018               433.000000
# 3      Hispanic or Latino     2018  2018              4753.000000
# 4      Hispanic or Latino     2018  2018              5148.000000
#
#                Geography  ID Geography        Slug Geography  Population  \
# 0  Montgomery County, TX  05000US48339  montgomery-county-tx       28628
# ...

# %%
df_data_2.shape
# Out:
# (84, 12)

# %%
df_diversity= df_data_2.drop(['ID Race' ,'ID Ethnicity','Ethnicity','ID Year','Year','Hispanic Population Moe','Geography','Slug Geography'], axis=1)

# %%
df_diversity
# Out:
#                                               Race  ID Geography  Population  \
# 0                  Black or African American Alone  05000US48339       28628
# 1                                Two or More Races  05000US48339        3709
# 2                                      White Alone  05000US48339      384260
# 3                            Some Other Race Alone  05000US48339       15247
# 4                                      White Alone  05000US48339      124234
# ..                                             ...           ...         ...
# 79                           Some Other Race Alone  05000US48339       24300
# 80                 Black or African American Alone  05000US48339         843
# 81  Native Hawaiian & Other Pacific Islander Alone  05000US48339          60
# 82                 Black or African American Alone  05000US48339       23503
# 83                                     Asian Alone  05000US48339         267
#
#        share
# 0   0.048446
# 1   0.006277
# ...

# %%
df_Pop=df_diversity.groupby('Race').sum()

# %%
df_Pop
# Out:
#                                                 Population     share
# Race
# American Indian & Alaska Native Alone                11406  0.020642
# Asian Alone                                          93399  0.170448
# Black or African American Alone                     160945  0.294273
# Native Hawaiian & Other Pacific Islander Alone        1361  0.002514
# Some Other Race Alone                               106320  0.197301
# Two or More Races                                    80786  0.147522
# White Alone                                        2819488  5.167299

# %%
df_Pop.plot(kind='barh')
plt.ylabel('Race')
plt.xlabel('Share' )
plt.title("Total Population as share")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
#Montgomery County Demography

N = 6
White = (0.860505, 0.865724, 0.863681, 0.849317, 0.870179,0.693982)
OtherRaces = (0.139495,0.134276, 0.136319, 0.150683, 0.129821, 0.142107)

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, White, width, label='White')
plt.bar(ind + width, OtherRaces, width,
    label='Other Races')

plt.ylabel('Diversity')
plt.title('Diversity By Race')

plt.xticks(ind + width / 2, ('2013', '2014', '2015', '2016', '2017','2018'))
plt.legend(loc='best')
plt.show()

# %%
body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='MedianHouseholdIncome.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#    ID Year  Year  Household Income by Race  Household Income by Race Moe  \
# 0     2018  2018                     99996                          4947
# 1     2018  2018                     99147                          4805
# 2     2018  2018                     80899                          2388
# 3     2018  2018                     59134                          2297
# 4     2018  2018                     60293                           140
#
#                                            Geography    ID Geography  \
# 0  Tomball City & The Woodlands (Southwest) PUMA, TX  79500US4804630
# 1  Montgomery County (South)The Woodlands (North)...  79500US4804503
# 2  Montgomery County (West)Conroe City (West) PUM...  79500US4804502
# 3  Montgomery County (Northeast)Conroe City (East...  79500US4804501
# 4                                      United States         01000US
#
#                                       Slug Geography
# 0       tomball-city-the-woodlands-southwest-puma-tx
# ...

# %%
# Median Household Income for The Woodlands city in camparision to Montgomery county

year = [2013, 2014, 2015, 2016, 2017, 2018]

MontgomeryCountyTX = [67766,68840,68838,70805,74323,77416]
TheWoodlandsTX = [106286,108635,109917,109605,115083,118836]
MontgomeryConroeCity = [72072, 72889, 74784, 75870,78789, 80899]
#MontgomeryCounty(Northeast)ConroeCity(East)PUMATX = [49476,50167,49664,50780,55248,59134]
HarrisCountyTX = [53137,53822,54457,55584,57791,60146]

plt.plot(year, MontgomeryCountyTX, label="Motgomery County")
plt.plot(year, TheWoodlandsTX, color='r',label="The Woodlands")
plt.plot(year, MontgomeryConroeCity, color ='orange', label = 'Montgomery Conroe' )
#plt.plot(year, MontgomeryCounty(Northeast)ConroeCity(East)PUMATX)
plt.plot(year, HarrisCountyTX, color='g', label= 'Harris County')

plt.xlabel('Montgomery County and The Woodlands')
plt.ylabel('Median Income')
plt.title('Median income for The Woodlands')
plt.legend(loc='best')
plt.show()

# %%
body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='Restaurant data for Montgomery county.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_4 = pd.read_csv(body)
df_data_4.head()
# Out:
#           ID PUMA                                               PUMA  ID Year  \
# 0  79500US4804630  Tomball City & The Woodlands (Southwest) PUMA, TX     2018
# 1  79500US4804630  Tomball City & The Woodlands (Southwest) PUMA, TX     2017
# 2  79500US4804630  Tomball City & The Woodlands (Southwest) PUMA, TX     2016
# 3  79500US4804630  Tomball City & The Woodlands (Southwest) PUMA, TX     2015
# 4  79500US4804630  Tomball City & The Woodlands (Southwest) PUMA, TX     2014
#
#    Year  Average Wage  Average Wage Appx MOE  Record Count  \
# 0  2018   17228.76633            7052.821717            26
# 1  2017   23499.23821            5816.868720            26
# 2  2016   15006.73928           11778.684210            20
# 3  2015   19361.88624            8045.138195            20
# 4  2014   22282.70507            8129.453414            14
#
#                  PUMS Industry
# 0  Restaurants & Food Services
# 1  Restaurants & Food Services
# 2  Restaurants & Food Services
# ...

# %%
df_data_4.shape
# Out:
# (21, 8)

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x="Year", y="PUMA", data=df_data_4)

# %%
df_dataM= df_data_4.drop(['ID PUMA','ID Year' ,'Average Wage Appx MOE','Record Count','PUMS Industry'], axis=1)

# %%
df_dataM.head(5)
# Out:
#                                                 PUMA  Year  Average Wage
# 0  Tomball City & The Woodlands (Southwest) PUMA, TX  2018   17228.76633
# 1  Tomball City & The Woodlands (Southwest) PUMA, TX  2017   23499.23821
# 2  Tomball City & The Woodlands (Southwest) PUMA, TX  2016   15006.73928
# 3  Tomball City & The Woodlands (Southwest) PUMA, TX  2015   19361.88624
# 4  Tomball City & The Woodlands (Southwest) PUMA, TX  2014   22282.70507

# %%
ax = sns.boxplot(x="Average Wage", y="PUMA",data=df_dataM)
#ax = sns.swarmplot(x="Year", y="PUMA", data=df_dataM, color=".25")

# %%
body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='Woodlands RandD.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_5 = pd.read_csv(body)
df_data_5.head()
# Out:
#    ID Race                                   Race  Year    Slug Geography  \
# 0        2  American Indian & Alaska Native Alone  2018  the-woodlands-tx
# 1        2  American Indian & Alaska Native Alone  2018  the-woodlands-tx
# 2        2  American Indian & Alaska Native Alone  2017  the-woodlands-tx
# 3        2  American Indian & Alaska Native Alone  2017  the-woodlands-tx
# 4        2  American Indian & Alaska Native Alone  2016  the-woodlands-tx
#
#    Population     share
# 0          66  0.000601
# 1          71  0.000646
# 2          76  0.000693
# 3          47  0.000429
# 4          51  0.000471

# %%
N = 6
White = (0.885894,0.881014,0.87152,0.872394,0.859353,0.852936)
OtherRaces = (0.114106,0.118986, 0.12848, 0.127606, 0.140647, 0.147064)

ind = np.arange(N) 
width = 0.35       
plt.bar(ind, White, width, label='White')
plt.bar(ind + width, OtherRaces, width,
    label='Other Races')

plt.ylabel('Diversity')
plt.title('Diversity By Race')

plt.xticks(ind + width / 2, ('2013', '2014', '2015', '2016', '2017','2018'))
plt.legend(loc='best')
plt.show()

# %%
body = client_9c414af691d04507b17dfb2555fe491b.get_object(Bucket='courseracapstone-donotdelete-pr-yav7pj2fth71uk',Key='The Woodlands Zip code.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_6 = pd.read_csv(body)
df_data_6.head()
# Out:
#    PartitionType    PartitionName  Latitude    Longitude
# 0        Zip Code           77385   30.1970     -95.4254
# 1        Zip Code           77380   30.1262     -95.4673
# 2        Zip Code           77381   30.1705 -955092.0000

# %%
map_TheWoodlands = folium.Map(location=[30.1658, -95.4613], zoom_start=10)

# %%
map_TheWoodlands
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = pd.DataFrame({
'lat':[30.1970,30.1262,30.1705 ],
'lon':[-95.4254,-95.4673,-955092 ],
'ZipCode':[77385,77380, 77381, ]
})
data
# Out:
#        lat          lon  ZipCode
# 0  30.1970     -95.4254    77385
# 1  30.1262     -95.4673    77380
# 2  30.1705 -955092.0000    77381

# %%
map_TheWoodlands = folium.Map(location=[30.1658, -95.4613], zoom_start=10)
for lat, lng, label in zip(data['lat'], data['lon'], data['ZipCode']):


    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_TheWoodlands)  
    
map_TheWoodlands
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
